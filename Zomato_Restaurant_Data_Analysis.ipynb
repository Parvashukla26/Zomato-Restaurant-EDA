# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_options_max_columns=100
df = pd.read_csv(r"C:\Users\PC\Desktop\DataSet\zomato_restaurants_in_India.csv")
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
df=round(df,2)
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
round(df.describe(),2)
# Out:
#             res_id    city_id   latitude  longitude  country_id  \
# count    211944.00  211944.00  211944.00  211944.00    211944.0
# mean   13494112.35    4746.79      21.50      77.62         1.0
# std     7883721.97    5568.77      22.78       7.50         0.0
# min          50.00       1.00       0.00       0.00         1.0
# 25%     3301027.00      11.00      15.50      74.88         1.0
# 50%    18695734.00      34.00      22.51      77.43         1.0
# 75%    18812974.00   11306.00      26.84      80.22         1.0
# max    19159790.00   11354.00   10000.00      91.83         1.0
#
#        average_cost_for_two  price_range  aggregate_rating      votes  \
# count             211944.00    211944.00         211944.00  211944.00
# mean                 595.81         1.88              3.40     378.00
# std                  606.24         0.89              1.28     925.33
# min                    0.00         1.00              0.00     -18.00
# ...

# %%
df.isnull().sum()
# Out:
# res_id                       0
# name                         0
# establishment                0
# url                          0
# address                    134
# city                         0
# city_id                      0
# locality                     0
# latitude                     0
# longitude                    0
# zipcode                 163187
# country_id                   0
# locality_verbose             0
# cuisines                  1391
# timings                   3874
# average_cost_for_two         0
# price_range                  0
# currency                     0
# highlights                   0
# aggregate_rating             0
# rating_text                  0
# votes                        0
# photo_count                  0
# opentable_support           48
# delivery                     0
# takeaway                     0
# dtype: int64

# %%
df = df.dropna(subset=['address', 'zipcode','cuisines','timings','opentable_support'])
df
# Out:
#           res_id                                name      establishment  \
# 1        3400005      Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                       Bhagat Halwai    ['Quick Bites']
# 3        3400290                       Bhagat Halwai    ['Quick Bites']
# 6        3400296                 Honeydew Restaurant    ['Quick Bites']
# 9        3400838                       Sugar N Thyme           ['Café']
# ...          ...                                 ...                ...
# 211929   3200477  Chhappanbhog Restaurant & Banquets  ['Casual Dining']
# 211930   3200560                         Mr Toasties    ['Quick Bites']
# 211932   3201502                         Cafe Madrid           ['Café']
# 211939   3202251      Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211943  18879846         Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# ...

# %%
df.isnull().sum()
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# zipcode                 0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# opentable_support       0
# delivery                0
# takeaway                0
# dtype: int64

# %%
df = df.fillna("")
df
# Out:
#           res_id                                name      establishment  \
# 1        3400005      Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                       Bhagat Halwai    ['Quick Bites']
# 3        3400290                       Bhagat Halwai    ['Quick Bites']
# 6        3400296                 Honeydew Restaurant    ['Quick Bites']
# 9        3400838                       Sugar N Thyme           ['Café']
# ...          ...                                 ...                ...
# 211929   3200477  Chhappanbhog Restaurant & Banquets  ['Casual Dining']
# 211930   3200560                         Mr Toasties    ['Quick Bites']
# 211932   3201502                         Cafe Madrid           ['Café']
# 211939   3202251      Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211943  18879846         Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# ...

# %%
df
# Out:
#           res_id                                name      establishment  \
# 1        3400005      Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                       Bhagat Halwai    ['Quick Bites']
# 3        3400290                       Bhagat Halwai    ['Quick Bites']
# 6        3400296                 Honeydew Restaurant    ['Quick Bites']
# 9        3400838                       Sugar N Thyme           ['Café']
# ...          ...                                 ...                ...
# 211929   3200477  Chhappanbhog Restaurant & Banquets  ['Casual Dining']
# 211930   3200560                         Mr Toasties    ['Quick Bites']
# 211932   3201502                         Cafe Madrid           ['Café']
# 211939   3202251      Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211943  18879846         Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# ...

# %%
df=df.drop(columns ='url')
df=df.drop(columns ='country_id')
df=df.drop(columns = 'city_id')
df=df.drop(columns ='currency')
df=df.drop(columns ='opentable_support')
df=df.drop(columns ='delivery')
df=df.drop(columns ='takeaway')
df=df.drop(columns ='timings')
df
# Out:
#           res_id                                name      establishment  \
# 1        3400005      Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                       Bhagat Halwai    ['Quick Bites']
# 3        3400290                       Bhagat Halwai    ['Quick Bites']
# 6        3400296                 Honeydew Restaurant    ['Quick Bites']
# 9        3400838                       Sugar N Thyme           ['Café']
# ...          ...                                 ...                ...
# 211929   3200477  Chhappanbhog Restaurant & Banquets  ['Casual Dining']
# 211930   3200560                         Mr Toasties    ['Quick Bites']
# 211932   3201502                         Cafe Madrid           ['Café']
# 211939   3202251      Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211943  18879846         Freshco's - The Health Cafe           ['Café']
#
#                                                   address      city  \
# ...

# %%
restaurants = df.drop_duplicates(subset='name')
top_10_Restaurant_rating = restaurants.sort_values( by='aggregate_rating',ascending=False)[['name', 'city','aggregate_rating']].head(10)
top_10_Restaurant_rating.reset_index(drop=True)
# Out:
#                                        name       city  aggregate_rating
# 0                                Buttercupp  Ahmedabad               4.9
# 1            Asia Kitchen By Mainland China  Bangalore               4.9
# 2                      Brahmin's Coffee Bar  Bangalore               4.9
# 3                   Meraki The Coffee House      Surat               4.9
# 4                 AB's - Absolute Barbecues  Bangalore               4.9
# 5                                 Communiti  Bangalore               4.9
# 6               Byg Brewski Brewing Company  Bangalore               4.9
# 7    Brew and Barbeque - A Microbrewery Pub  Bangalore               4.9
# 8  Girish Chandra Dey & Nakur Chandra Nandy    Kolkata               4.9
# 9                               Cafe Paashh       Pune               4.9

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(12,6))
sns.barplot(data= top_10_Restaurant_rating,x='aggregate_rating',y = 'name',hue='name',palette='viridis', legend=False)
plt.title('Top 10 Restaurants in India by Rating', fontsize=16)
plt.xlabel('Aggregate Rating')
plt.ylabel('Restaurant Name')
plt.tight_layout()
plt.show()
